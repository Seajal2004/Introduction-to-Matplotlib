# %% [markdown]
# ## Intrduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() #creates a figure
ax =  fig.add_subplot() #adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() #creates a figure
ax =  fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some data
plt.show()

# %%
# 3rd method (recommended)
fig,ax = plt.subplots()
ax.plot(x,y);
type(fig), type(ax) #figures are like base canvas and axes are like we are drawing on that canvas
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Preapre data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. setup plot
fig,ax = plt.subplots(figsize = (10 ,10))

#3. plot the data
ax.plot(x,y)

#4. customize plots
ax.set(title = "simple plot",
       xlabel = "x-axis",
       ylabel = "y-axis")

#5. Save ans show (you save the whole figure)
fig.savefig("numpy-images")

# %% [markdown]
# ## MAking figures with numpy arrays
#  we want:
#  1. line plot
#  2. scatter plot
#  3. bar plot
#  4. hist
#  5. subplot

# %%
import numpy as np

# %%
#create data
x = np.linspace(0,10,100)#return evenly spaces number over a specified interval.
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#Plot the data and create a line plot
fig , ax = plt.subplots()
ax.plot(x, x**2);

# %%
# use same data to mmake a scatter 
fig , ax = plt.subplots()
ax.scatter(x , np.exp(x));

# %%
#another scattter plot
fig , ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# make a plot from dictionary
nut_butter_prices = {"Almond butter" : 10,
                     "Peanut butter" : 8,
                     "cashew butter" : 12}
fig , ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title = "Nut butter Stock",
      ylabel = "Price");

# %%
fig , ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# make some data for histograms and plot it
x = np.random.randn(1000)
fig , ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two options for subplots

# %%
# subplot option-1
fig, ((ax1, ax2) , (ax3 , ax4)) = plt.subplots(nrows = 2,
                                                ncols = 2,
                                                figsize = (10,5))
# Plot to each different axis
ax1.plot(x , x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
## subplots Option 2
fig , ax = plt.subplots(nrows = 2,
                       ncols = 2,
                        figsize = (10,5))
#Plot to each diff index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas dataframe

# %%
import pandas as pd

# %%
# make a dataframe
car_sales = pd.read_csv("car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2024', periods=1000))

ts = ts.cumsum()

ts.plot()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# Remove last two zeros
car_sales["Prices"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Prices  Sale-Date  Total Sales
# 0  Toyota  White         150043      4   400000   4000 2024-01-01       400000
# 1   Honda    Red          87899      4   500000   5000 2024-01-02       900000
# 2  Toyota   Blue          32549      3   700000   7000 2024-01-03      1600000
# 3     BMW  Black          11179      5  2200000  22000 2024-01-04      3800000
# 4  Nissan  White         213095      4   350000   3500 2024-01-05      4150000
# 5  Toyota  Green          99213      4   450000   4500 2024-01-06      4600000
# 6   Honda   Blue          45698      4   750000   7500 2024-01-07      5350000
# 7   Honda   Blue          54738      4   700000   7000 2024-01-08      6050000
# 8  Toyota  White          60000      4   625000   6250 2024-01-09      6675000
# 9  Nissan  White          31600      4   970000   9700 2024-01-10      7645000

# %%
car_sales["Sale-Date"] = pd.date_range(start="1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Prices  Sale-Date  Total Sales
# 0  Toyota  White         150043      4   400000   4000 2024-01-01       400000
# 1   Honda    Red          87899      4   500000   5000 2024-01-02       900000
# 2  Toyota   Blue          32549      3   700000   7000 2024-01-03      1600000
# 3     BMW  Black          11179      5  2200000  22000 2024-01-04      3800000
# 4  Nissan  White         213095      4   350000   3500 2024-01-05      4150000
# 5  Toyota  Green          99213      4   450000   4500 2024-01-06      4600000
# 6   Honda   Blue          45698      4   750000   7500 2024-01-07      5350000
# 7   Honda   Blue          54738      4   700000   7000 2024-01-08      6050000
# 8  Toyota  White          60000      4   625000   6250 2024-01-09      6675000
# 9  Nissan  White          31600      4   970000   9700 2024-01-10      7645000

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Prices  Sale-Date  Total Sales
# 0  Toyota  White         150043      4   400000   4000 2024-01-01       400000
# 1   Honda    Red          87899      4   500000   5000 2024-01-02       900000
# 2  Toyota   Blue          32549      3   700000   7000 2024-01-03      1600000
# 3     BMW  Black          11179      5  2200000  22000 2024-01-04      3800000
# 4  Nissan  White         213095      4   350000   3500 2024-01-05      4150000
# 5  Toyota  Green          99213      4   450000   4500 2024-01-06      4600000
# 6   Honda   Blue          45698      4   750000   7500 2024-01-07      5350000
# 7   Honda   Blue          54738      4   700000   7000 2024-01-08      6050000
# 8  Toyota  White          60000      4   625000   6250 2024-01-09      6675000
# 9  Nissan  White          31600      4   970000   9700 2024-01-10      7645000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# Lets Plot the total sales
car_sales.plot(x="Sale-Date", y="Total Sales" );

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot( x= "Odometer (KM)" , y = "Price" , kind = "scatter");

# %%
## How about a bar graph?
x = np.random.rand(10, 4)
x
 # turn it into a dataframe
df = pd.DataFrame(x , columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.238155  0.318268  0.375283  0.255780
# 1  0.891367  0.219752  0.018402  0.657785
# 2  0.059518  0.359291  0.369279  0.920922
# 3  0.969727  0.246673  0.897777  0.548821
# 4  0.126206  0.921550  0.680727  0.528173
# 5  0.585448  0.464642  0.952173  0.454302
# 6  0.062556  0.833171  0.728996  0.275793
# 7  0.305630  0.894110  0.711305  0.657252
# 8  0.206114  0.815920  0.641106  0.288709
# 9  0.585094  0.996960  0.659540  0.749402

# %%
df.plot.bar();

# %%
df.plot(kind = "bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Prices  Sale-Date  Total Sales
# 0  Toyota  White         150043      4   400000   4000 2024-01-01       400000
# 1   Honda    Red          87899      4   500000   5000 2024-01-02       900000
# 2  Toyota   Blue          32549      3   700000   7000 2024-01-03      1600000
# 3     BMW  Black          11179      5  2200000  22000 2024-01-04      3800000
# 4  Nissan  White         213095      4   350000   3500 2024-01-05      4150000
# 5  Toyota  Green          99213      4   450000   4500 2024-01-06      4600000
# 6   Honda   Blue          45698      4   750000   7500 2024-01-07      5350000
# 7   Honda   Blue          54738      4   700000   7000 2024-01-08      6050000
# 8  Toyota  White          60000      4   625000   6250 2024-01-09      6675000
# 9  Nissan  White          31600      4   970000   9700 2024-01-10      7645000

# %%
car_sales.plot(x = "Make" , y= "Odometer (KM)" , kind = "bar" );

# %%
# Histograms?
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind = "hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=50);

# %% [markdown]
# ## Lets try on another dataset

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Create a hist
heart_disease["age"].plot.hist(bins = 20);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize = (10,30), subplots = True);

# %% [markdown]
# ### Which one should you use? (pyplot  vs matplotlib OO method)
# * When plotting something quickly, okay to use the pyplot method
# * when plotting something more advanced use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50 ]

over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %%
# Pyplot method
over_50.plot(kind ="scatter",
             x = "age",
             y = "chol",
             c= "target");

# %%
# OO method mix with pyplot method
fix, ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = 'scatter',
x = "age",
y = "chol",
c = "target",
ax =ax);

#ax.set_xlim([45,100]);

# %%
## OO method from scratch (object-oriented method )
fig , ax = plt.subplots(figsize = (10,6))
#Plot the data
scatter = ax.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"])
#customize the plot
ax.set(title = "Heart Disease",
       xlabel = "age",
       ylabel = "chol")

# add a legend
ax.legend(*scatter.legend_elements(), title = "Target");

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle = "--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age, thalach
fig ,(ax0 , ax1) = plt.subplots(nrows = 2,
                                ncols = 1,
                                figsize = (10,10))
# add data to ax0
scatter = ax0.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"])
# customize ax0
ax0.set(title = " Heart",
        xlabel = "age",
        ylabel = "chol")

# add a legend 
ax0.legend(*scatter.legend_elements(), title = "Target")
# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle = "--");



# add data to ax1
scatter = ax1.scatter(x = over_50["age"],
                     y = over_50["thalach"],
                     c = over_50["target"])
# customize ax1
ax1.set(title = " Heart Disease and Max heart Rate",
        xlabel = " Max age",
        ylabel = "thalach")

# add a legend 
ax1.legend(*scatter.legend_elements(), title = "Target")
# add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle = "--");

# add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize = 16 , fontweight = "bold");

# %% [markdown]
# ## customizing matplot plot and getting stylish

# %%
# see the different style
import matplotlib.pyplot as plt

# Check the available styles
available_styles = plt.style.available

available_styles
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use( 'seaborn-v0_8')

# %%
car_sales["Price"].plot();

# %%
# create some data
x = np.random.randn(10,4)
x
# Out:
# array([[-0.42946089,  0.27703126, -0.0644702 ,  1.39909753],
#        [-0.03458478, -0.76392112,  0.26772886, -0.06756453],
#        [ 1.54637114, -0.29793479,  1.54370284,  0.39600004],
#        [-0.28863086, -0.42078816,  1.01821358,  0.76862611],
#        [-0.32878123, -0.65762669,  1.33929386,  0.4400405 ],
#        [ 1.01262006, -0.28513535,  1.8730519 ,  1.1720188 ],
#        [ 1.31402687, -1.14708608, -0.6905434 ,  1.36781449],
#        [-0.30632532,  1.51977341, -0.14982474, -0.84629621],
#        [ 0.72657072,  0.21139311, -1.0617563 ,  0.87549323],
#        [ 1.29924823, -1.16334651,  0.30320367, -0.12101048]])

# %%
df = pd.DataFrame(x , columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.429461  0.277031 -0.064470  1.399098
# 1 -0.034585 -0.763921  0.267729 -0.067565
# 2  1.546371 -0.297935  1.543703  0.396000
# 3 -0.288631 -0.420788  1.018214  0.768626
# 4 -0.328781 -0.657627  1.339294  0.440040
# 5  1.012620 -0.285135  1.873052  1.172019
# 6  1.314027 -1.147086 -0.690543  1.367814
# 7 -0.306325  1.519773 -0.149825 -0.846296
# 8  0.726571  0.211393 -1.061756  0.875493
# 9  1.299248 -1.163347  0.303204 -0.121010

# %%
ax = df.plot(kind = 'bar');

# %%
# customize our plot with the set() method
ax = df.plot(kind='bar')
# add some label and title
ax.set(title = "Random Number",
       xlabel = "Row number",
       ylabel = "random number")
#make the legend visible
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-v0_8-whitegrid')

## OO method from scratch (object-oriented method )
fig , ax = plt.subplots(figsize = (10,6))
#Plot the data
scatter = ax.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"],
                     cmap = "winter" #this changes the color scheme
                     
                    )
#customize the plot
ax.set(title = "Heart Disease",
       xlabel = "age",
       ylabel = "chol")

# add a legend
ax.legend(*scatter.legend_elements(), title = "Target");

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle = "--");

# %%
#customizing the x and y limitations
# subplot of chol, age, thalach
fig ,(ax0 , ax1) = plt.subplots(nrows = 2,
                                ncols = 1,
                                figsize = (10,10))
# add data to ax0
scatter = ax0.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"],
                     cmap = "winter")
# customize ax0
ax0.set(title = " Heart",
        xlabel = "age",
        ylabel = "chol")
# change x axis limits 
ax0.set_xlim([50, 80])# change x axis limits 

# add a legend 
ax0.legend(*scatter.legend_elements(), title = "Target")
# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle = "--");



# add data to ax1
scatter = ax1.scatter(x = over_50["age"],
                     y = over_50["thalach"],
                     c = over_50["target"],
                     cmap = "winter")
# customize ax1
ax1.set(title = " Heart Disease and Max heart Rate",
        xlabel = " Max age",
        ylabel = "thalach")

ax1.set_xlim([50, 80])# change x axis limits 
ax1.set_ylim([60, 200])# change x axis limits 


# add a legend 
ax1.legend(*scatter.legend_elements(), title = "Target")
# add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle = "--");

# add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize = 16 , fontweight = "bold");

# %%
fig

# %%
fig.savefig("Heart-Disease-Analysis-plot-saved-with-code.png")
